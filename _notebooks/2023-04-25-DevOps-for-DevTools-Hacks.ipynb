# %% [markdown]
# # DevOps for Devtools Hacks

# %% [markdown]
# ## AWS Database Hacks

# %% [markdown]
# ### Quiz 1 (AWS Databases)

# %% [markdown]
# - Note: Answers are bolded.

# %% [markdown]
# What is the main difference between relational and non-relational databases?
#
# A. Relational databases are only used for structured data, while non-relational databases are only used for unstructured data.
#
# B. Relational databases can easily handle high data volumes, while non-relational databases cannot.
#
# **C. Relational databases are based on tables and use SQL, while non-relational databases are based on collections and use JSON-like documents.**
#
# D. Relational databases are more expensive than non-relational databases.
#
# Which AWS database service is best suited for applications that require low-latency speed?
#
# **A. Amazon ElastiCache**
#
# B. Amazon Neptune
#
# C. Amazon DocumentDB
#
# D. Amazon RDS
#
# What is the purpose of the code example provided in the lesson?
#
# A. To demonstrate how to create a table in Amazon Aurora.
#
# B. To show how to query data from a DynamoDB table.
#
# **C. To provide an example of how to connect to a database instance in RDS using Python.**
#
# D. To showcase how to insert data into a MySQL table.

# %% [markdown]
# ### Quiz 2 (Guide to SQLite vs AWS alternate databases)

# %% [markdown]
# - Note: Answers are bolded.

# %% [markdown]
# Which of the following is not an AWS database option?
#
# A. Amazon RDS
#
# B. Amazon Neptune
#
# **C. SQLite**
#
# D. Amazon DynamoDB
#
# Which of the following is a file-based, lightweight RDBMS?
#
# A. Amazon RDS
#
# B. Amazon Neptune
#
# C Amazon DynamoDB
#
# **D. SQLite**
#
# Which AWS service enables you to store and query highly connected datasets?
#
# A. Amazon Relational Database Service (RDS)
#
# B. Amazon DynamoDB
#
# **C. Amazon Neptune**
#
# D. Amazon DocumentDB

# %% [markdown]
# ## Certbot Hacks

# %% [markdown]
# ### Hack 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hack 2

# %% [markdown]
# - OpenSSL and LibreSSL are 2 widely used libraries that give access to enhanced security for many different applications. Both libraries include security features that support a variety of algorithms to ensure safety. Additionally, they can generate random keys. Some errors are that it can spread information to the wrong people (hackers).

# %% [markdown]
# ## KASM Hacks

# %% [markdown]
# ### Hack 1

# %% [markdown]
# - Virtual systems allow people to access a complete desktop environment from anywhere. KASM provides a secure and controlled environment for us to collaborate on various different things and make many projects together. In an APCSP environment, this can be used to ensure collaboration and complete work in any place with an internet connection. Additionally, it also has great security features which ensures that all the information being put is secure.

# %% [markdown]
# ### Hack 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Duck DNS and AWS Hacks

# %% [markdown]
# ### Hack 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hack 2

# %% [markdown]
# - We use DuckDNS because it helps us assign a domain name to an ip address. It automatically updates the DNS records for the domain that the user chooses. We use DuckDNS specifically because it s a free, efficient, and easy to use service. It is useful for our projects because it can access many of the not secure pages that we use such as the flask. Additionally, it is also useful if the user wants to change his/her IP address.
#
# - To set up DuckDNS you make an account in their website, creating a subdomain, and configuring it with the current IP address, click the update ip button.

# %% [markdown]
# ### Hack 4

# %% [markdown]
# - Some confusions that I had was that I didnt know the difference between Docker and a Nginx Unit (I know now). Nginx is a lightweight web application that runs a variety of different things. Additionally, I also had confusions about if Nginx can be ran in a container but I then found out that the user will get a connection error if Docker is not running at the same time.

# %% [markdown]
# ### Hack 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Hack 6

# %% [markdown]
# ![image.png](attachment:image.png)
